# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt

# %%
data = keras.datasets.fashion_mnist

# %%
# %matplotlib inline

# %%
(train_images, train_labels), (test_images, test_labels) = data.load_data()

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %%
plt.imshow(train_images[7], cmap=plt.cm.binary)
plt.show()

# %%
train_images = train_images / 255.0
test_images = test_images / 255.0

# %% [markdown]
# # Defining the model

# %%
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dense(10, activation='softmax')
])

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.fit(train_images, train_labels, epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 1.6667 - accuracy: 0.8052
# Epoch 2/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 1.6204 - accuracy: 0.8427
# Epoch 3/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 1.6079 - accuracy: 0.8547
# Epoch 4/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 1.6021 - accuracy: 0.8599
# Epoch 5/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 1.5946 - accuracy: 0.8677
# Epoch 6/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 1.5916 - accuracy: 0.8704
# Epoch 7/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 1.5895 - accuracy: 0.8722
# Epoch 8/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 1.5852 - accuracy: 0.8765
# Epoch 9/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 1.5817 - accuracy: 0.8801
# Epoch 10/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 1.5801 - accuracy: 0.8813

# %%
test_loss, test_acc = model.evaluate(test_images,  test_labels, verbose=2)

print('\nTested accuracy:', test_acc)
# Out:
# 313/313 - 1s - loss: 1.6154 - accuracy: 0.8456
#
# Tested accuracy: 0.8456000089645386

# %%
prediction = model.predict(test_images)

# %%
plt.figure(figsize=(25,25))
for i in range(10):
    plt.subplot(5, 5, i+1)
    plt.grid(False)
    plt.imshow(test_images[i], cmap=plt.cm.binary)
    plt.xlabel("Actual Label " + class_names[test_labels[i]])
    plt.ylabel("Predicted Label " + class_names[np.argmax(prediction[i])])
plt.show()
